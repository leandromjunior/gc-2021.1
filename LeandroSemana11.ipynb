# %%
import pandas as pd
import numpy as np

# %% [markdown]
# [Ranking de games vendidos no Kaggle](https://www.kaggle.com/gregorut/videogamesales?select=vgsales.csv)

# %%
games = pd.read_csv("https://raw.githubusercontent.com/ValdisE/datasets/master/video-game-sales.csv")

# %%
games
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16598 rows x 11 columns]

# %%
games.describe()
# Out:
#                Rank          Year  ...   Other_Sales  Global_Sales
# count  16598.000000  16327.000000  ...  16598.000000  16598.000000
# mean    8300.605254   2006.406443  ...      0.048063      0.537441
# std     4791.853933      5.828981  ...      0.188588      1.555028
# min        1.000000   1980.000000  ...      0.000000      0.010000
# 25%     4151.250000   2003.000000  ...      0.000000      0.060000
# 50%     8300.500000   2007.000000  ...      0.010000      0.170000
# 75%    12449.750000   2010.000000  ...      0.040000      0.470000
# max    16600.000000   2020.000000  ...     10.570000     82.740000
#
# [8 rows x 7 columns]

# %%
games[games['Global_Sales']>=40]
# Out:
#    Rank               Name Platform  ...  JP_Sales Other_Sales Global_Sales
# 0     1         Wii Sports      Wii  ...      3.77        8.46        82.74
# 1     2  Super Mario Bros.      NES  ...      6.81        0.77        40.24
#
# [2 rows x 11 columns]

# %%
publisher = games[games['Publisher']== "Activision"]

# %%
publisher
# Out:
#         Rank  ... Global_Sales
# 29        30  ...        14.76
# 31        32  ...        14.64
# 33        34  ...        14.24
# 34        35  ...        14.03
# 35        36  ...        13.73
# ...      ...  ...          ...
# 16411  16414  ...         0.01
# 16444  16447  ...         0.01
# 16501  16504  ...         0.01
# 16537  16540  ...         0.01
# 16595  16598  ...         0.01
#
# [975 rows x 11 columns]

# %%
publisher.head(40)
# Out:
#      Rank  ... Global_Sales
# 29     30  ...        14.76
# 31     32  ...        14.64
# 33     34  ...        14.24
# 34     35  ...        14.03
# 35     36  ...        13.73
# 36     37  ...        13.51
# 37     38  ...        13.46
# 40     41  ...        12.73
# 55     56  ...        10.69
# 61     62  ...        10.21
# 67     68  ...         9.59
# 70     71  ...         9.32
# 93     94  ...         7.60
# 98     99  ...         7.37
# 101   102  ...         7.30
# 120   121  ...         6.72
# 137   138  ...         6.28
# 154   155  ...         5.65
# 166   167  ...         5.43
# 181   182  ...         5.20
# 193   194  ...         5.13
# 202   203  ...         5.02
# 207   208  ...         4.98
# 217   218  ...         4.83
# 225   226  ...         4.68
# 230   231  ...         4.62
# 237   238  ...         4.53
# 239   240  ...         4.50
# 241   242  ...         4.48
# 244   245  ...         4.45
# 248   249  ...         4.41
# 257   258  ...         4.31
# ...

# %% [markdown]
# *   Nome: Leandro Motta Junior
# *   Matricula: 0050014733
#
# *   O fator que mais me chamou atenção, foi a quantidade de gigantesca de jogos de apenas uma produtora dentre tantos presentes no ranking
